# %% [markdown]
# # ACTIVITY 2
# Nama : Elsa Elisa Yohana Sianturi
# <br> NIM : 122140135

# %%
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np

# Visualisasi sinyal
plt.figure(figsize=(15, 7))
plt.plot(data['time'], data['amplitude'], label='Signal')
plt.title('Signal Visualization')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.legend()
plt.show()

# Menyimpan sinyal ke dalam variabel signal_nim
signal_nim = data['amplitude'].values

# %% [markdown]
# ## Penjelasan
# Gambar diatas adalah visualisasi sinyal sesuai dengan file csv dengan NIM saya yaitu 122140135.
# <br/>Kemudian saya menyimpan sinyal diatas ke dalam variabel dengan nama signal_nim dengan menyimoan nilai dari amplitude yang terdapat dalam file csv.

# %% [markdown]
# # Analisis Sinyal FFT

# %%
# Menghitung FFT
fft_result = np.fft.fft(signal_nim)
fft_magnitude = np.abs(fft_result) / len(signal_nim)
frequency = np.fft.fftfreq(len(signal_nim), d=1/sampling_frequency)

# Visualisasi FFT
plt.figure(figsize=(15, 7))
plt.plot(frequency[:len(frequency)//2], fft_magnitude[:len(frequency)//2])
plt.title('FFT of the Signal')
plt.xlim([0, 50])  # Limit frekuensi 0-50 Hz
plt.axvline(x=2, color='r', linestyle='--', alpha=0.5)  #Mark di frekuensi 2 Hz
plt.axvline(x=9, color='g', linestyle='--', alpha=0.5)  #Mark di frekuensi 9 Hz
plt.axvline(x=11, color='r', linestyle='--', alpha=0.5)  #Mark di frekuensi 11 Hz
plt.axvline(x=20, color='g', linestyle='--', alpha=0.5)  #Mark di frekuensi 20 Hz
plt.axvline(x=39, color='r', linestyle='--', alpha=0.5)  #Mark di frekuensi 39 Hz
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Penjelasan
# Dari visualisasi sinyal di atas, dapat dilihat bahwa frekuensi 11 Hz dominan dalam sinyal tersebut. Hal ini dapat diketahui daren frekuensi ini memiliki nilai magnitude paling tinggi. Selain itu juga masih terdapat beberapa nilai frekuensi yang masih terlihat signifikan dominan, diantaranya frekuensi 39 Hz, kemudian frekuensi 11 Hz, 2 Hz dan 20 Hz.

# %% [markdown]
# # Filtering Band Pass

# %%
from scipy.signal import butter, lfilter

lowcut = 9.5
highcut = 12.5

b, a = butter(3, [lowcut, highcut], fs=fs, btype='band')
filtered_signal = lfilter(b, a, signal_nim)

plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time_axis, signal_nim)
plt.title('Original Signal')
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(time_axis, filtered_signal, 'r-')
plt.title('Filtered Signal (9.5 Hz -  12.5 Hz Bandpass)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Penjelasan
# Pada sinyal_nim dilakukan band pass filtering  dengan low cut nya 9.5 Hz dan High cutnya 12.5 Hz.
# Filtering ini diterapkan pada nilai frekuensi dengan magnitude tertinggi yaitu 11 Hz dengan nilai order nya sebesar 3. Visualisasi perbedaan sinyal antara sebelum dan sesudah dilakukan filtering dapat dilihat pada gambar yang ada di atas. Sinyal yang dihasilkan setelah filtering lebih jernih, dan hampir menyerupai sinyal aslinya.

# %% [markdown]
# ## Referensi
# Menggunakan Chat GPT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
